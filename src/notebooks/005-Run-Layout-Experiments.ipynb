# %% [markdown]
# # Layout Params

# %%
# !python layout_beam_experiments_1_1.py
# Out:
# I1001 03:20:58.541450 281473238364176 pipeline.py:188] Missing pipeline option (runner). Executing pipeline using the default runner: DirectRunner.
# Running 1 hp tasks for LayOut
# I1001 03:20:58.818036 281473238364176 environments.py:376] Default Python SDK image for environment is apache/beam_python3.9_sdk:2.46.0
# I1001 03:20:58.838427 281473238364176 translations.py:710] ==================== <function annotate_downstream_side_inputs at 0xffff3c7a1550> ====================
# I1001 03:20:58.838603 281473238364176 translations.py:710] ==================== <function fix_side_input_pcoll_coders at 0xffff3c7a1670> ====================
# I1001 03:20:58.838671 281473238364176 translations.py:710] ==================== <function pack_combiners at 0xffff3c7a1b80> ====================
# I1001 03:20:58.838843 281473238364176 translations.py:710] ==================== <function lift_combiners at 0xffff3c7a1c10> ====================
# ...

# %%
# !python tiles_beam_experiments.py
